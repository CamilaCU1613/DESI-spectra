# %%
from astropy.io import fits
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.utils.data import get_pkg_data_filename
from astropy.convolution import convolve, Gaussian1DKernel

# %% [markdown]
# # targets-bright-hp-0.fits

# %% [markdown]
# Este catalogo contiene más información util para astrometría. No lo usaremos.

# %%
archivo_fits = fits.open('targets-bright-hp-0.fits') #open file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 archivo_fits = fits.open('targets-bright-hp-0.fits')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:175, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     172 if not name:
#     173     raise ValueError(f'Empty filename: {name!r}')
# --> 175 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     176                         lazy_load_hdus, ignore_missing_simple, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:410, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     398 @classmethod
#     399 def fromfile(cls, fileobj, mode=None, memmap=None,
#     400              save_backup=False, cache=True, lazy_load_hdus=True,
#     401              ignore_missing_simple=False, **kwargs):
#     402     """
#     403     Creates an `HDUList` instance from a file-like object.
#     404
#    (...)
#     407     documentation for details of the parameters accepted by this method).
#     408     """
# --> 410     return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     411                          save_backup=save_backup, cache=cache,
#     412                          ignore_missing_simple=ignore_missing_simple,
#     413                          lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:1060, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1057 if fileobj is not None:
#    1058     if not isinstance(fileobj, _File):
#    1059         # instantiate a FITS file object (ffo)
# -> 1060         fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1061     # The Astropy mode is determined by the _File initializer if the
#    1062     # supplied mode was None
#    1063     mode = fileobj.mode
#
# File C:\ProgramData\anaconda3\Lib\site-packages\astropy\io\fits\file.py:170, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     168     self._open_fileobj(fileobj, mode, overwrite)
#     169 elif isinstance(fileobj, (str, bytes)):
# --> 170     self._open_filename(fileobj, mode, overwrite)
#     171 else:
#     172     self._open_filelike(fileobj, mode, overwrite)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\astropy\io\fits\file.py:562, in _File._open_filename(self, filename, mode, overwrite)
#     559 ext = os.path.splitext(self.name)[1]
#     561 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 562     self._file = open(self.name, IO_FITS_MODES[mode])
#     563     self.close_on_error = True
#     565 # Make certain we're back at the beginning of the file
#     566 # BZ2File does not support seek when the file is open for writing, but
#     567 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'targets-bright-hp-0.fits'

# %%
archivo_fits.info() #resume el contenido de la tabla

# %%
archivo_fits[1].header #Asi accedemos al contenido de la tabla. El indice indica a cual fila ingresamos

# %%
archivo_fits[1].data['RA'] #Asi seleccionamos uno de los Header mostrados antes

# %% [markdown]
# # coadd-sv3-backup-10016.fits
# Index of /public/edr/spectro/redux/fuji/healpix/sv3/backup/100/10016/

# %% [markdown]
# Este catalogo es el que más nos parece adecuado para buscar y graficar espectros por noches.

# %%
archivo_fits = fits.open('coadd-sv3-backup-10016.fits') #open file

# %%
archivo_fits.info() #resume el contenido de la tabla
# Out:
# Filename: coadd-sv3-backup-10016.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      60   ()
#   1  FIBERMAP      1 BinTableHDU    197   9R x 70C   [K, J, D, D, E, E, E, K, B, 3A, D, J, I, 8A, J, J, 4A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, K, 2A, E, E, E, E, 1A, K, K, K, K, K, K, K, K, K, D, D, I, E, I, I, E, E, E, E, D, E, D, E, E]
#   2  EXP_FIBERMAP    1 BinTableHDU     64   16R x 26C   [K, J, D, J, J, D, J, D, I, J, K, J, J, E, E, E, D, D, K, D, D, D, D, D, D, D]
#   3  B_WAVELENGTH    1 ImageHDU        10   (2751,)   float64
#   4  B_FLUX        1 ImageHDU        11   (2751, 9)   float32
#   5  B_IVAR        1 ImageHDU        11   (2751, 9)   float32
#   6  B_MASK        1 ImageHDU        12   (2751, 9)   int32 (rescales to uint32)
#   7  B_RESOLUTION    1 ImageHDU        11   (2751, 11, 9)   float32
#   8  R_WAVELENGTH    1 ImageHDU        10   (2326,)   float64
#   9  R_FLUX        1 ImageHDU        11   (2326, 9)   float32
#  10  R_IVAR        1 ImageHDU        11   (2326, 9)   float32
#  11  R_MASK        1 ImageHDU        12   (2326, 9)   int32 (rescales to uint32)
#  12  R_RESOLUTION    1 ImageHDU        11   (2326, 11, 9)   float32
#  13  Z_WAVELENGTH    1 ImageHDU        10   (2881,)   float64
#  14  Z_FLUX        1 ImageHDU        11   (2881, 9)   float32
#  15  Z_IVAR        1 ImageHDU        11   (2881, 9)   float32
#  16  Z_MASK        1 ImageHDU        12   (2881, 9)   int32 (rescales to uint32)
#  17  Z_RESOLUTION    1 ImageHDU        11   (2881, 11, 9)   float32
#  18  SCORES        1 BinTableHDU     96   9R x 42C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
archivo_fits[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  341 / length of dimension 1
# NAXIS2  =                    9 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   70 / number of table fields
# TTYPE1  = 'TARGETID'
# TFORM1  = 'K       '
# TTYPE2  = 'COADD_FIBERSTATUS'
# TFORM2  = 'J       '
# TTYPE3  = 'TARGET_RA'
# TFORM3  = 'D       '
# TTYPE4  = 'TARGET_DEC'
# TFORM4  = 'D       '
# TTYPE5  = 'PMRA    '
# TFORM5  = 'E       '
# TTYPE6  = 'PMDEC   '
# TFORM6  = 'E       '
# TTYPE7  = 'REF_EPOCH'
# TFORM7  = 'E       '
# TTYPE8  = 'FA_TARGET'
# TFORM8  = 'K       '
# TTYPE9  = 'FA_TYPE '
# TFORM9  = 'B       '
# TTYPE10 = 'OBJTYPE '
# TFORM10 = '3A      '
# TTYPE11 = 'SUBPRIORITY'
# TFORM11 = 'D       '
# TTYPE12 = 'OBSCONDITIONS'
# TFORM12 = 'J       '
# TTYPE13 = 'RELEASE '
# TFORM13 = 'I       '
# TTYPE14 = 'BRICKNAME'
# TFORM14 = '8A      '
# TTYPE15 = 'BRICKID '
# TFORM15 = 'J       '
# TTYPE16 = 'BRICK_OBJID'
# TFORM16 = 'J       '
# TTYPE17 = 'MORPHTYPE'
# TFORM17 = '4A      '
# TTYPE18 = 'EBV     '
# TFORM18 = 'E       '
# TTYPE19 = 'FLUX_G  '
# TFORM19 = 'E       '
# TTYPE20 = 'FLUX_R  '
# TFORM20 = 'E       '
# TTYPE21 = 'FLUX_Z  '
# TFORM21 = 'E       '
# TTYPE22 = 'FLUX_W1 '
# TFORM22 = 'E       '
# TTYPE23 = 'FLUX_W2 '
# TFORM23 = 'E       '
# TTYPE24 = 'FLUX_IVAR_G'
# TFORM24 = 'E       '
# TTYPE25 = 'FLUX_IVAR_R'
# TFORM25 = 'E       '
# TTYPE26 = 'FLUX_IVAR_Z'
# TFORM26 = 'E       '
# TTYPE27 = 'FLUX_IVAR_W1'
# TFORM27 = 'E       '
# TTYPE28 = 'FLUX_IVAR_W2'
# TFORM28 = 'E       '
# TTYPE29 = 'FIBERFLUX_G'
# TFORM29 = 'E       '
# TTYPE30 = 'FIBERFLUX_R'
# TFORM30 = 'E       '
# TTYPE31 = 'FIBERFLUX_Z'
# TFORM31 = 'E       '
# TTYPE32 = 'FIBERTOTFLUX_G'
# TFORM32 = 'E       '
# TTYPE33 = 'FIBERTOTFLUX_R'
# TFORM33 = 'E       '
# TTYPE34 = 'FIBERTOTFLUX_Z'
# TFORM34 = 'E       '
# TTYPE35 = 'MASKBITS'
# TFORM35 = 'I       '
# TTYPE36 = 'SERSIC  '
# TFORM36 = 'E       '
# TTYPE37 = 'SHAPE_R '
# TFORM37 = 'E       '
# TTYPE38 = 'SHAPE_E1'
# TFORM38 = 'E       '
# TTYPE39 = 'SHAPE_E2'
# TFORM39 = 'E       '
# TTYPE40 = 'REF_ID  '
# TFORM40 = 'K       '
# TTYPE41 = 'REF_CAT '
# TFORM41 = '2A      '
# TTYPE42 = 'GAIA_PHOT_G_MEAN_MAG'
# TFORM42 = 'E       '
# TTYPE43 = 'GAIA_PHOT_BP_MEAN_MAG'
# TFORM43 = 'E       '
# TTYPE44 = 'GAIA_PHOT_RP_MEAN_MAG'
# TFORM44 = 'E       '
# TTYPE45 = 'PARALLAX'
# TFORM45 = 'E       '
# TTYPE46 = 'PHOTSYS '
# TFORM46 = '1A      '
# TTYPE47 = 'PRIORITY_INIT'
# TFORM47 = 'K       '
# TTYPE48 = 'NUMOBS_INIT'
# TFORM48 = 'K       '
# TTYPE49 = 'SV3_DESI_TARGET'
# TFORM49 = 'K       '
# TTYPE50 = 'SV3_BGS_TARGET'
# TFORM50 = 'K       '
# TTYPE51 = 'SV3_MWS_TARGET'
# TFORM51 = 'K       '
# TTYPE52 = 'SV3_SCND_TARGET'
# TFORM52 = 'K       '
# TTYPE53 = 'DESI_TARGET'
# TFORM53 = 'K       '
# TTYPE54 = 'BGS_TARGET'
# TFORM54 = 'K       '
# TTYPE55 = 'MWS_TARGET'
# TFORM55 = 'K       '
# TTYPE56 = 'PLATE_RA'
# TFORM56 = 'D       '
# TTYPE57 = 'PLATE_DEC'
# TFORM57 = 'D       '
# TTYPE58 = 'COADD_NUMEXP'
# TFORM58 = 'I       '
# TTYPE59 = 'COADD_EXPTIME'
# TFORM59 = 'E       '
# TTYPE60 = 'COADD_NUMNIGHT'
# TFORM60 = 'I       '
# TTYPE61 = 'COADD_NUMTILE'
# TFORM61 = 'I       '
# TTYPE62 = 'MEAN_DELTA_X'
# TFORM62 = 'E       '
# TTYPE63 = 'RMS_DELTA_X'
# TFORM63 = 'E       '
# TTYPE64 = 'MEAN_DELTA_Y'
# TFORM64 = 'E       '
# TTYPE65 = 'RMS_DELTA_Y'
# TFORM65 = 'E       '
# TTYPE66 = 'MEAN_FIBER_RA'
# TFORM66 = 'D       '
# TTYPE67 = 'STD_FIBER_RA'
# TFORM67 = 'E       '
# TTYPE68 = 'MEAN_FIBER_DEC'
# TFORM68 = 'D       '
# TTYPE69 = 'STD_FIBER_DEC'
# TFORM69 = 'E       '
# TTYPE70 = 'MEAN_PSF_TO_FIBER_SPECFLUX'
# TFORM70 = 'E       '
# ENCODING= 'ascii   '
# EXTNAME = 'FIBERMAP'
# LONGSTRN= 'OGIP 1.0'
# DEPNAM00= 'python  '
# DEPVER00= '3.9.7   '
# DEPNAM01= 'numpy   '
# DEPVER01= '1.21.4  '
# DEPNAM02= 'scipy   '
# DEPVER02= '1.7.3   '
# DEPNAM03= 'astropy '
# DEPVER03= '5.0     '
# DEPNAM04= 'yaml    '
# DEPVER04= '6.0     '
# DEPNAM05= 'matplotlib'
# DEPVER05= '3.5.1   '
# DEPNAM06= 'fitsio  '
# DEPVER06= '1.1.6   '
# DEPNAM07= 'healpy  '
# DEPVER07= '1.15.0  '
# DEPNAM08= 'desiutil'
# DEPVER08= '3.2.5   '
# DEPNAM09= 'desispec'
# DEPVER09= '0.51.8  '
# DEPNAM10= 'desitarget'
# DEPVER10= '2.4.0   '
# DEPNAM11= 'desimodel'
# DEPVER11= '0.17.0  '
# DEPNAM12= 'specter '
# DEPVER12= '0.10.0  '
# DEPNAM13= 'speclite'
# DEPVER13= '0.15    '
# DEPNAM14= 'DESI_ROOT'
# DEPVER14= '/global/cfs/cdirs/desi'
# DEPNAM15= 'DESI_SPECTRO_DATA'
# DEPVER15= '/global/cfs/cdirs/desi/spectro/data'
# DEPNAM16= 'DESI_SPECTRO_REDUX'
# DEPVER16= '/global/cfs/cdirs/desi/spectro/redux'
# DEPNAM17= 'SPECPROD'
# DEPVER17= 'fuji    '
# DEPNAM18= 'DESI_SPECTRO_CALIB'
# DEPVER18= '/global/cfs/cdirs/desi/spectro/desi_spectro_calib/0.3.1'
# DEPNAM19= 'DESI_BASIS_TEMPLATES'
# DEPVER19= '/global/cfs/cdirs/desi/spectro/templates/basis_templates/v3.2'
# DEPNAM20= 'DESI_TARGET'
# DEPVER20= '/global/cfs/cdirs/desi/target'
# DEPNAM21= 'DESIMODEL'
# DEPVER21= '/global/common/software/desi/cori/desiconda/20211217-2.0.0/code/des&'
# CONTINUE  'imodel/0.17.0'
# CHECKSUM= 'Uai6VaZ3Uaf3UaZ3'   / HDU checksum updated 2022-02-15T22:09:07
# DATASUM = '4225357668'         / data unit checksum updated 2022-02-15T22:09:07

# %%
Table.read(archivo_fits, hdu=1) #De esta tabla podemos extraer los TARGET ID y validar el sepctype en otro catalogo
# Out:
# <Table length=9>
#       TARGETID      COADD_FIBERSTATUS ... MEAN_PSF_TO_FIBER_SPECFLUX
#        int64              int32       ...          float32
# ------------------- ----------------- ... --------------------------
# 2305843019716235906                 0 ...                 0.79392904
#  616093919289017142                 0 ...                 0.79434526
# 2305843019716232322                 0 ...                 0.79443026
#  616093919289017218          16777216 ...                 0.79402626
# 2305843019716236594          16777216 ...                 0.79447687
# 2305843019716235023                 0 ...                   0.794168
#            -3745505               515 ...                        0.0
#  616093919289017038                 0 ...                  0.7925254
# 2305843019716233633              1032 ...                 0.79662114

# %%
archivo_fits[14].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2881
# NAXIS2  =                    9
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'Z_FLUX  '           / extension name
# BUNIT   = '10**-17 erg/(s cm2 Angstrom)'
# CHECKSUM= '2U7a4T5U2T5Z2T5Z'   / HDU checksum updated 2022-02-15T22:09:07
# DATASUM = '2722859522'         / data unit checksum updated 2022-02-15T22:09:07

# %%
archivo_fits[14].data
# Out:
# array([[29.384806  , 26.901798  , 21.927593  , ..., 19.94164   ,
#         20.756145  , 15.9839945 ],
#        [-0.44302306,  0.21667023, -1.0068816 , ...,  0.8047688 ,
#         -2.308117  ,  0.37252367],
#        [24.7406    , 24.187798  , 30.598436  , ..., 14.399642  ,
#         13.709883  , 10.853569  ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.5704736 , -0.9058871 , -0.61248606, ..., -0.1943168 ,
#          0.2962273 , -0.99085647],
#        [ 9.487678  ,  7.006179  ,  8.452967  , ...,  5.4688406 ,
#          3.8125587 ,  4.984337  ]], dtype=float32)

# %% [markdown]
# Como se ve en el 'archivo_fits[14].data' aparece una matriz, o lista de listas, en donde cada fila corresponde al flujo de 9 objetos distintos. Esto se describe en las dimensiones dadas por el 'archivo_fits[14].header'. Para graficar uno de los espectros en especifico, hacemos lo siguiente:

# %%
archivo_fits[14].data[0]
# Out:
# array([29.384806 , 26.901798 , 21.927593 , ..., 19.94164  , 20.756145 ,
#        15.9839945], dtype=float32)

# %%
archivo_fits[14].data[1] # y asi hasta 9, dependiendo del objeto del que queramos saber el espectro.
# Out:
# array([-0.44302306,  0.21667023, -1.0068816 , ...,  0.8047688 ,
#        -2.308117  ,  0.37252367], dtype=float32)

# %% [markdown]
# Graficaremos el flujo con el filtro z contra las longitudes de onda de dicho filtro. En otro ejemplo mostramos que podemos unir todos los filtros para armar el espectro completo del objeto.

# %%
y=archivo_fits[14].data[1]
x=archivo_fits[13].data

plt.figure()
plt.plot(x,y, color='k')
plt.xlabel("Z_wavelenght")
plt.ylabel("Z_flux")
plt.show()

# %% [markdown]
# Podemos abrir la información de otra manera y graficar todo el espectro uniendo las mediciones de los tres filtros de color usados:

# %%
espc= fits.open('coadd-sv3-backup-10016.fits') 
espc.info()
# Out:
# Filename: coadd-sv3-backup-10016.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      60   ()
#   1  FIBERMAP      1 BinTableHDU    197   9R x 70C   [K, J, D, D, E, E, E, K, B, 3A, D, J, I, 8A, J, J, 4A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, K, 2A, E, E, E, E, 1A, K, K, K, K, K, K, K, K, K, D, D, I, E, I, I, E, E, E, E, D, E, D, E, E]
#   2  EXP_FIBERMAP    1 BinTableHDU     64   16R x 26C   [K, J, D, J, J, D, J, D, I, J, K, J, J, E, E, E, D, D, K, D, D, D, D, D, D, D]
#   3  B_WAVELENGTH    1 ImageHDU        10   (2751,)   float64
#   4  B_FLUX        1 ImageHDU        11   (2751, 9)   float32
#   5  B_IVAR        1 ImageHDU        11   (2751, 9)   float32
#   6  B_MASK        1 ImageHDU        12   (2751, 9)   int32 (rescales to uint32)
#   7  B_RESOLUTION    1 ImageHDU        11   (2751, 11, 9)   float32
#   8  R_WAVELENGTH    1 ImageHDU        10   (2326,)   float64
#   9  R_FLUX        1 ImageHDU        11   (2326, 9)   float32
#  10  R_IVAR        1 ImageHDU        11   (2326, 9)   float32
#  11  R_MASK        1 ImageHDU        12   (2326, 9)   int32 (rescales to uint32)
#  12  R_RESOLUTION    1 ImageHDU        11   (2326, 11, 9)   float32
#  13  Z_WAVELENGTH    1 ImageHDU        10   (2881,)   float64
#  14  Z_FLUX        1 ImageHDU        11   (2881, 9)   float32
#  15  Z_IVAR        1 ImageHDU        11   (2881, 9)   float32
#  16  Z_MASK        1 ImageHDU        12   (2881, 9)   int32 (rescales to uint32)
#  17  Z_RESOLUTION    1 ImageHDU        11   (2881, 11, 9)   float32
#  18  SCORES        1 BinTableHDU     96   9R x 42C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
archivo3 = Table.read(espc, hdu=1)
print (archivo3)
print(archivo3.columns)
# Out:
#       TARGETID      COADD_FIBERSTATUS ... MEAN_PSF_TO_FIBER_SPECFLUX
# ------------------- ----------------- ... --------------------------
# 2305843019716235906                 0 ...                 0.79392904
#  616093919289017142                 0 ...                 0.79434526
# 2305843019716232322                 0 ...                 0.79443026
#  616093919289017218          16777216 ...                 0.79402626
# 2305843019716236594          16777216 ...                 0.79447687
# 2305843019716235023                 0 ...                   0.794168
#            -3745505               515 ...                        0.0
#  616093919289017038                 0 ...                  0.7925254
# 2305843019716233633              1032 ...                 0.79662114
# <TableColumns names=('TARGETID','COADD_FIBERSTATUS','TARGET_RA','TARGET_DEC','PMRA','PMDEC','REF_EPOCH','FA_TARGET','FA_TYPE','OBJTYPE','SUBPRIORITY','OBSCONDITIONS','RELEASE','BRICKNAME','BRICKID','BRICK_OBJID','MORPHTYPE','EBV','FLUX_G','FLUX_R','FLUX_Z','FLUX_W1','FLUX_W2','FLUX_IVAR_G','FLUX_IVAR_R','FLUX_IVAR_Z','FLUX_IVAR_W1','FLUX_IVAR_W2','FIBERFLUX_G','FIBERFLUX_R','FIBERFLUX_Z','FIBERTOTFLUX_G','FIBERTOTFLUX_R','FIBERTOTFLUX_Z','MASKBITS','SERSIC','SHAPE_R','SHAPE_E1','SHAPE_E2','REF_ID','REF_CAT','GAIA_PHOT_G_MEAN_MAG','GAIA_PHOT_BP_MEAN_MAG','GAIA_PHOT_RP_MEAN_MAG','PARALLAX','PHOTSYS','PRIORITY_INIT','NUMOBS_INIT','SV3_DESI_TARGET','SV3_BGS_TARGET','SV3_MWS_TARGET','SV3_SCND_TARGET','DESI_TARGET','BGS_TARGET','MWS_TARGET','PLATE_RA','PLATE_DEC','COADD_NUMEXP','COADD_EXPTIME','COADD_NUMNIGHT','COADD_NUMTILE','MEAN_DELTA_X','RMS_DELTA_X','MEAN_DELTA_Y','RMS_DELTA_Y','MEAN_FIBER_RA','STD_FIBER_RA','MEAN_FIBER_DEC','STD_FIBER_DEC','MEAN_PSF_TO_FIBER_SPECFLUX')>

# %%
xb=espc[4].data[0] #B_Flux espectro 0
yb=espc[3].data #B_wavelenght
xr=espc[9].data[0] #R_flux espectro 0
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[0] #Z_Flux espectro 0
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title("STAR 2305843019716235906")
plt.show()

# %%
archivo3 = Table.read(espc, hdu=1)
print (archivo3)
print(archivo3.columns)
# Out:
#       TARGETID      COADD_FIBERSTATUS ... MEAN_PSF_TO_FIBER_SPECFLUX
# ------------------- ----------------- ... --------------------------
# 2305843019716235906                 0 ...                 0.79392904
#  616093919289017142                 0 ...                 0.79434526
# 2305843019716232322                 0 ...                 0.79443026
#  616093919289017218          16777216 ...                 0.79402626
# 2305843019716236594          16777216 ...                 0.79447687
# 2305843019716235023                 0 ...                   0.794168
#            -3745505               515 ...                        0.0
#  616093919289017038                 0 ...                  0.7925254
# 2305843019716233633              1032 ...                 0.79662114
# <TableColumns names=('TARGETID','COADD_FIBERSTATUS','TARGET_RA','TARGET_DEC','PMRA','PMDEC','REF_EPOCH','FA_TARGET','FA_TYPE','OBJTYPE','SUBPRIORITY','OBSCONDITIONS','RELEASE','BRICKNAME','BRICKID','BRICK_OBJID','MORPHTYPE','EBV','FLUX_G','FLUX_R','FLUX_Z','FLUX_W1','FLUX_W2','FLUX_IVAR_G','FLUX_IVAR_R','FLUX_IVAR_Z','FLUX_IVAR_W1','FLUX_IVAR_W2','FIBERFLUX_G','FIBERFLUX_R','FIBERFLUX_Z','FIBERTOTFLUX_G','FIBERTOTFLUX_R','FIBERTOTFLUX_Z','MASKBITS','SERSIC','SHAPE_R','SHAPE_E1','SHAPE_E2','REF_ID','REF_CAT','GAIA_PHOT_G_MEAN_MAG','GAIA_PHOT_BP_MEAN_MAG','GAIA_PHOT_RP_MEAN_MAG','PARALLAX','PHOTSYS','PRIORITY_INIT','NUMOBS_INIT','SV3_DESI_TARGET','SV3_BGS_TARGET','SV3_MWS_TARGET','SV3_SCND_TARGET','DESI_TARGET','BGS_TARGET','MWS_TARGET','PLATE_RA','PLATE_DEC','COADD_NUMEXP','COADD_EXPTIME','COADD_NUMNIGHT','COADD_NUMTILE','MEAN_DELTA_X','RMS_DELTA_X','MEAN_DELTA_Y','RMS_DELTA_Y','MEAN_FIBER_RA','STD_FIBER_RA','MEAN_FIBER_DEC','STD_FIBER_DEC','MEAN_PSF_TO_FIBER_SPECFLUX')>

# %% [markdown]
# A continuación graficamos varios espectros utilizando este catalogo:

# %%
xb=espc[4].data[1] #B_Flux espectro 1
yb=espc[3].data #B_wavelenght
xr=espc[9].data[1] #R_flux espectro 1
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[1] #Z_Flux espectro 1
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('GALAXY 616093919289017142')
plt.show()

# %%
xb=espc[4].data[2] #B_Flux espectro 2
yb=espc[3].data #B_wavelenght
xr=espc[9].data[2] #R_flux espectro 2
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[2] #Z_Flux espectro 2
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('STAR 2305843019716232322')
plt.show()

# %%
xb=espc[4].data[3] #B_Flux espectro 3
yb=espc[3].data #B_wavelenght
xr=espc[9].data[3] #R_flux espectro 3
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[3] #Z_Flux espectro 3
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('GALAXY 616093919289017218')
plt.show()

# %%
xb=espc[4].data[4] #B_Flux espectro 4
yb=espc[3].data #B_wavelenght
xr=espc[9].data[4] #R_flux espectro 4
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[4] #Z_Flux espectro 4
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('STAR 2305843019716236594')
plt.show()

# %%
xb=espc[4].data[5] #B_Flux espectro 5
yb=espc[3].data #B_wavelenght
xr=espc[9].data[5] #R_flux espectro 5
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[5] #Z_Flux espectro 5
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('STAR 2305843019716235023')
plt.show()

# %%
xb=espc[4].data[6] #B_Flux espectro 6
yb=espc[3].data #B_wavelenght
xr=espc[9].data[6] #R_flux espectro 6
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[6] #Z_Flux espectro 6
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('STAR -3745505')
plt.show()

# %%
xb=espc[4].data[7] #B_Flux espectro 7
yb=espc[3].data #B_wavelenght
xr=espc[9].data[7] #R_flux espectro 7
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[7] #Z_Flux espectro 7
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('GALAXY 616093919289017038')
plt.show()

# %%
xb=espc[4].data[8] #B_Flux espectro 8
yb=espc[3].data #B_wavelenght
xr=espc[9].data[8] #R_flux espectro 8
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[8] #Z_Flux espectro 8
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('STAR 2305843019716233633')
plt.show()

# %% [markdown]
# # redrock-sv3-bright-10016.fits

# %%
archivo_fits = fits.open('redrock-sv3-bright-10016.fits') #open file
archivo_fits.info()
# Out:
# Filename: redrock-sv3-bright-10016.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   ()
#   1  REDSHIFTS     1 BinTableHDU     32   43R x 11C   [K, D, D, K, D, 10D, K, 6A, 20A, K, D]
#   2  FIBERMAP      1 BinTableHDU    149   43R x 70C   [K, J, D, D, E, E, E, K, B, 3A, D, J, I, 8A, J, J, 4A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, K, 2A, E, E, E, E, 1A, K, K, K, K, K, K, K, K, K, D, D, I, E, I, I, E, E, E, E, D, E, D, E, E]
#   3  EXP_FIBERMAP    1 BinTableHDU     61   127R x 26C   [K, J, D, J, J, D, J, D, I, J, K, J, J, E, E, E, D, D, K, D, D, D, D, D, D, D]
#   4  TSNR2         1 BinTableHDU     75   43R x 33C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
archivo3 = Table.read(archivo_fits, hdu=1)
print (archivo3)
print(archivo3.columns)
# Out:
#      TARGETID                 Z            ... NCOEFF       DELTACHI2
# ------------------ ----------------------- ... ------ ---------------------
#  39633166985596095      0.2004070714061304 ...     10     110.9653980191797
#  39633166985595463      0.5871044714721063 ...     10    43.300490248948336
#  39633166985595831     0.11461802505772073 ...     10    1471.8782742507756
#  39633166985594393 -0.00011616095484868146 ...      5    13.456326764454388
#  39633166985595580      0.2646107427988541 ...     10     722.8006576299667
#  39633166985595026        0.99002536109193 ...     10    12.660422444343567
#           -3635505  -0.0019956912923479522 ...      3 1.942668892225729e+84
#  39633166985594891      0.3459440224358845 ...     10    1266.9839819073677
# 616093919289017109      1.1853548372032894 ...     10    0.6416594535112381
#  39633171263783206     0.20071362182001806 ...     10     50.20940579473972
#                ...                     ... ...    ...                   ...
#  39633171259590660 -5.0692876361078875e-05 ...      5    16775.299115462207
#           -3695505  -0.0019956912923479522 ...      3 1.942668892225729e+84
#  39633166985595660  -0.0019956912923479522 ...      3 1.942668892225729e+84
#  39633166985595446  -0.0008184799009154923 ...      5    3571.1343171672042
#  39633166985595695     0.11545423231860066 ...     10    244.79885862767696
#           -3725474  -0.0019956912923479522 ...      3 1.942668892225729e+84
#           -3725510  -0.0019956912923479522 ...      3 1.942668892225729e+84
#           -3725509  -0.0019956912923479522 ...      3 1.942668892225729e+84
#           -3725521  -0.0019956912923479522 ...      3 1.942668892225729e+84
#  39633171259591193      0.3989784825497951 ...     10     345.1991082429886
#  39633166985594300      0.3227887955885254 ...     10    323.22173534473404
# Length = 43 rows
# <TableColumns names=('TARGETID','Z','ZERR','ZWARN','CHI2','COEFF','NPIXELS','SPECTYPE','SUBTYPE','NCOEFF','DELTACHI2')>

# %%
archivo_fits[1].data['SPECTYPE']
# Out:
# chararray(['GALAXY', 'GALAXY', 'GALAXY', 'STAR', 'GALAXY', 'GALAXY',
#            'STAR', 'GALAXY', 'GALAXY', 'GALAXY', 'QSO', 'GALAXY',
#            'GALAXY', 'STAR', 'GALAXY', 'GALAXY', 'GALAXY', 'GALAXY',
#            'GALAXY', 'STAR', 'GALAXY', 'GALAXY', 'GALAXY', 'STAR',
#            'GALAXY', 'STAR', 'STAR', 'GALAXY', 'STAR', 'STAR', 'GALAXY',
#            'GALAXY', 'STAR', 'STAR', 'STAR', 'STAR', 'GALAXY', 'STAR',
#            'STAR', 'STAR', 'STAR', 'GALAXY', 'GALAXY'], dtype='<U6')

# %%
616093919289017142 in archivo_fits[1].data['TARGETID'] #No coinsiden los targetid con los espectros de la misma noche
# Out:
# False

# %% [markdown]
# # coadd-sv3-backup-28030.fits
# Este es otro catalogo con espectros en otra noche. Los graficaremos para ver qué obtenemos.

# %%
archivo_fits = fits.open('coadd-sv3-backup-28030.fits') #open file

# %%
archivo_fits.info()
# Out:
# Filename: coadd-sv3-backup-28030.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      60   ()
#   1  FIBERMAP      1 BinTableHDU    197   36R x 70C   [K, J, D, D, E, E, E, K, B, 3A, D, J, I, 8A, J, J, 4A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, E, E, E, E, K, 2A, E, E, E, E, 1A, K, K, K, K, K, K, K, K, K, D, D, I, E, I, I, E, E, E, E, D, E, D, E, E]
#   2  EXP_FIBERMAP    1 BinTableHDU     64   36R x 26C   [K, J, D, J, J, D, J, D, I, J, K, J, J, E, E, E, D, D, K, D, D, D, D, D, D, D]
#   3  B_WAVELENGTH    1 ImageHDU        10   (2751,)   float64
#   4  B_FLUX        1 ImageHDU        11   (2751, 36)   float32
#   5  B_IVAR        1 ImageHDU        11   (2751, 36)   float32
#   6  B_MASK        1 ImageHDU        12   (2751, 36)   int32 (rescales to uint32)
#   7  B_RESOLUTION    1 ImageHDU        11   (2751, 11, 36)   float32
#   8  R_WAVELENGTH    1 ImageHDU        10   (2326,)   float64
#   9  R_FLUX        1 ImageHDU        11   (2326, 36)   float32
#  10  R_IVAR        1 ImageHDU        11   (2326, 36)   float32
#  11  R_MASK        1 ImageHDU        12   (2326, 36)   int32 (rescales to uint32)
#  12  R_RESOLUTION    1 ImageHDU        11   (2326, 11, 36)   float32
#  13  Z_WAVELENGTH    1 ImageHDU        10   (2881,)   float64
#  14  Z_FLUX        1 ImageHDU        11   (2881, 36)   float32
#  15  Z_IVAR        1 ImageHDU        11   (2881, 36)   float32
#  16  Z_MASK        1 ImageHDU        12   (2881, 36)   int32 (rescales to uint32)
#  17  Z_RESOLUTION    1 ImageHDU        11   (2881, 11, 36)   float32
#  18  SCORES        1 BinTableHDU     96   36R x 42C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
archivo3 = Table.read(archivo_fits, hdu=1)
print (archivo_fits[1].data['TARGETID'])
# Out:
# [ 39633166985596095  39633166985595463  39633166985595831
#   39633166985594393  39633166985595580  39633166985595026
#            -3635505  39633166985594891 616093919289017109
#   39633171263783206  39633166985595371  39633166985596017
#   39633171259591119           -3665521  39633171259590480
#   39633171259591299  39633171259592406  39633171259590847
#   39633166985594086           -3665452  39633166985595443
#   39633166985594798  39633166985595441  39633166985595145
#   39633171259592104           -3695521  39633171259591553
#   39633166985595671  39633166985596938  39633171259590303
#   39633166985594263  39633166985595239  39633171259590660
#            -3695505  39633166985595660  39633166985595446
#   39633166985595695           -3725474           -3725510
#            -3725509           -3725521  39633171259591193
#   39633166985594300]

# %%
xb=espc[4].data[0] #B_Flux espectro 0
yb=espc[3].data #B_wavelenght
xr=espc[9].data[0] #R_flux espectro 0
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[0] #Z_Flux espectro 0
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('GALAXY 39633166985596095')
plt.show()

# %%
xb=espc[4].data[8] #B_Flux espectro 8
yb=espc[3].data #B_wavelenght
xr=espc[9].data[8] #R_flux espectro 8
yr=espc[8].data  #R_wavelenght
xz=espc[14].data[8] #Z_Flux espectro 8
yz=espc[13].data #Z_wavelenght



plt.figure(figsize = (20, 6))
# Plot the spectrum from each arm (B,R,Z) in blue, green, red

plt.plot(yb, xb, color = 'b', alpha = 0.5)
plt.plot(yr, xr, color = 'g', alpha = 0.5)
plt.plot(yz, xz, color = 'r', alpha = 0.5)
# Over-plotting smoothed spectra in black for all the three arms
plt.plot(yb, convolve(xb, Gaussian1DKernel(5)), color = 'k')
plt.plot(yr, convolve(xr, Gaussian1DKernel(5)), color = 'k')
plt.plot(yz, convolve(xz, Gaussian1DKernel(5)), color = 'k')
plt.xlabel('$\lambda$ [$\AA$]')
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.title('GALAXY 39633166985594891')
plt.show()
